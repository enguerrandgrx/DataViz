# %%
import numpy as np
import pandas as pd
import os
from collections import Counter

# %%
import datetime as dt

# %%
adresses = os.path.join('paradisepanamapapers', 'Addresses.csv')
all_edges = os.path.join('paradisepanamapapers', 'all_edges.csv')
entities = os.path.join('paradisepanamapapers', 'entities.csv')
intermediaires = os.path.join('paradisepanamapapers', 'intermediaries.csv')
officers = os.path.join('paradisepanamapapers', 'officers.csv')

# %% [markdown]
# ## Adresse Dataframe

# %%
df_addr = pd.read_csv(adresses, dtype = {'note': str})

# %%
print('The dataset involve {} entries'.format(df_addr.size))
# Out:
# The dataset involve 1212840 entries

# %%
df_addr.head()
# Out:
#                                              address  \
# 0       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1            "Almaly Village" v.5, Almaty Kazakhstan
# 2  "Cantonia" South Road St Georges Hill Weybridg...
# 3  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
#
#                             icij_id  \
# 0  6991059DFFB057DF310B9BF31CC4A0E6
# 1  C65A269424AA1A8BBAC416FA30150938
# 2  240EE44DFB70AF775E6CD02AF8CB889B
# 3  340C6D3D2FC60AE58C53BB3618129C43
# 4  6DBCD74F5AAB63EABC166885CE8CD7CD
#
#                                        valid_until country_codes  \
# 0  The Panama Papers  data is current through 2015           SGP
# 1  The Panama Papers  data is current through 2015           KAZ
# 2  The Panama Papers  data is current through 2015           GBR
# 3  The Panama Papers  data is current through 2015           GGY
# 4  The Panama Papers  data is current through 2015           KEN
#
#         countries   node_id       sourceID note
# 0       Singapore  14000001  Panama Papers  NaN
# 1      Kazakhstan  14000002  Panama Papers  NaN
# 2  United Kingdom  14000003  Panama Papers  NaN
# 3        Guernsey  14000004  Panama Papers  NaN
# 4           Kenya  14000005  Panama Papers  NaN

# %%
df_addr['address'][2]
# Out:
# '"Cantonia" South Road St Georges Hill Weybridge, Surrey'

# %%
Counter(df_addr['note'])
# Out:
# Counter({nan: 151582, 'Record manually added from leaked documents': 23})

# %%
Counter(df_addr['valid_until'])
# Out:
# Counter({'The Bahamas Leaks data is current through early 2016.': 551,
#          'The Offshore Leaks data is current through 2010': 57600,
#          'The Panama Papers  data is current through 2015': 93454})

# %%
Counter(df_addr['sourceID'])
# Out:
# Counter({'Bahamas Leaks': 551,
#          'Offshore Leaks': 57600,
#          'Panama Papers': 93454})

# %% [markdown]
# - valid_until is irrevelant since there is no more information than in sourceID so we will drop this col
# - node_id is the id of a node who symbolise a company or individual
# - sourceID is the leak information come from
# - note indicated if the record was manually added - only 23 record have this note - so we can also drop this col

# %%
df_addr = df_addr.drop('valid_until', 1)

# %%
df_addr['sourceID'] =  df_addr['sourceID'].astype('category')
df_addr['country_codes'] =  df_addr['country_codes'].astype('category')
df_addr['countries'] =  df_addr['countries'].astype('category')

# %%
df_addr.dtypes
# Out:
# address            object
# icij_id            object
# country_codes    category
# countries        category
# node_id             int64
# sourceID         category
# note               object
# dtype: object

# %%
import geocoder

# %%
geocoder.google??

# %% [markdown]
# Words to remove:
# - No

# %%
addr = df_addr['address'][1551]
print(addr)
# Out:
# 1000 WAVERLY WAY KIRKLAND WA 98033-4806 INARY SHS

# %%
for i in range(10):
    print(geocoder.google(addr, methods = 'places').latlng)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
df_addr['lat'] = 0
df_addr['long'] = 0

# %%
df_addr.head()
# Out:
#                                              address  \
# 0       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1            "Almaly Village" v.5, Almaty Kazakhstan
# 2  "Cantonia" South Road St Georges Hill Weybridg...
# 3  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
#
#                             icij_id country_codes       countries   node_id  \
# 0  6991059DFFB057DF310B9BF31CC4A0E6           SGP       Singapore  14000001
# 1  C65A269424AA1A8BBAC416FA30150938           KAZ      Kazakhstan  14000002
# 2  240EE44DFB70AF775E6CD02AF8CB889B           GBR  United Kingdom  14000003
# 3  340C6D3D2FC60AE58C53BB3618129C43           GGY        Guernsey  14000004
# 4  6DBCD74F5AAB63EABC166885CE8CD7CD           KEN           Kenya  14000005
#
#         sourceID note  lat  long
# 0  Panama Papers  NaN    0     0
# 1  Panama Papers  NaN    0     0
# 2  Panama Papers  NaN    0     0
# 3  Panama Papers  NaN    0     0
# 4  Panama Papers  NaN    0     0

# %%
test = [43.7373086, 7.425639199999999]

# %%
type(test)
# Out:
# list

# %%
test = '"Cantonia" South Road St Georges Hill Weybridg...'

# %%
len(test.split('"', 2))
# Out:
# 3

# %%
for i in range(len(df_addr['address'])): 
    addr = df_addr['address'][i]
    if(df_addr['lat'][i] == 0):
        print('acctually at step {}'.format(i))
        #
        result = geocoder.google(addr, methods = 'places').latlng
        if(type(result) == list): 
                print(result)
                df_addr.loc[i, 'lat'] = result[0]
                df_addr.loc[i, 'long'] = result[1]
        else:
            for j in range(5):
                result = geocoder.google(addr, methods = 'places').latlng
                if(type(result) == list):
                    print(result)
                    df_addr.loc[i, 'lat'] = result[0]
                    df_addr.loc[i, 'long'] = result[1]
                    break
            addr = addr.split('"',2)
            if(len(addr) == 3):
                addr = addr[2]
                for j in range(5):
                    result = geocoder.google(addr, methods = 'places').latlng
                    if(type(result) == list):
                        print(result)
                        df_addr.loc[i, 'lat'] = result[0]
                        df_addr.loc[i, 'long'] = result[1]
                        break
# Out:
# acctually at step 4
# acctually at step 10
# acctually at step 12
# acctually at step 18
# acctually at step 20
# acctually at step 23
# acctually at step 24
# Status code 500 from https://maps.googleapis.com/maps/api/geocode/json: ERROR - 500 Server Error: Internal Server Error for url: https://maps.googleapis.com/maps/api/geocode/json?address=%23103%3B+FU+XING+NANG+RD.%3B+XIAO+AD+TOWN%3B+YAN+JIANG+CITY%3B+FU+ZHOU%3B+CHINA&bounds=&components=&region=&language=
# Status code 500 from https://maps.googleapis.com/maps/api/geocode/json: ERROR - 500 Server Error: Internal Server Error for url: https://maps.googleapis.com/maps/api/geocode/json?address=%23103%3B+FU+XING+NANG+RD.%3B+XIAO+AD+TOWN%3B+YAN+JIANG+CITY%3B+FU+ZHOU%3B+CHINA&bounds=&components=&region=&language=
# acctually at step 25
# acctually at step 30
# acctually at step 33
# acctually at step 34
# acctually at step 35
# acctually at step 36
# Status code 500 from https://maps.googleapis.com/maps/api/geocode/json: ERROR - 500 Server Error: Internal Server Error for url: https://maps.googleapis.com/maps/api/geocode/json?address=%2311+ZHI+PING+ROAD%3B+ZHI+JIANG+HUA+YUAN%3B+HANG+ZHOU%3B+ZHE+JIANG%3B+CHINA&bounds=&components=&region=&language=
# acctually at step 38
# acctually at step 43
# Status code 500 from https://maps.googleapis.com/maps/api/geocode/json: ERROR - 500 Server Error: Internal Server Error for url: https://maps.googleapis.com/maps/api/geocode/json?address=%231306+Jin+Lai+Building+5+Ma+Street+Plaza++Lu+District+Wen+Zhou%3B+Zhejiang%3B+China&bounds=&components=&region=&language=
# acctually at step 51
# acctually at step 52
# acctually at step 54
# acctually at step 55
# acctually at step 59
# acctually at step 60
# acctually at step 71
# acctually at step 72
# acctually at step 73
# acctually at step 74
# acctually at step 77
# acctually at step 86
# acctually at step 87
# acctually at step 88
# acctually at step 89
# acctually at step 91
# acctually at step 92
# acctually at step 93
# acctually at step 94
# acctually at step 95
# acctually at step 96
# acctually at step 97
# acctually at step 98
# acctually at step 99
# acctually at step 100
# acctually at step 101
# acctually at step 102
# acctually at step 103
# acctually at step 104
# acctually at step 105
# acctually at step 106
# acctually at step 107
# acctually at step 108
# acctually at step 109
# acctually at step 110
# acctually at step 111
# acctually at step 112
# acctually at step 113
# acctually at step 114
# acctually at step 115
# acctually at step 116
# acctually at step 117
# acctually at step 120
# acctually at step 124
# acctually at step 127
# acctually at step 128
# acctually at step 130
# acctually at step 133
# acctually at step 134
# acctually at step 143
# acctually at step 147
# acctually at step 148
# acctually at step 150
# acctually at step 152
# acctually at step 157
# acctually at step 158
# acctually at step 159
# acctually at step 160
# acctually at step 162
# acctually at step 164
# acctually at step 165
# acctually at step 167
# acctually at step 171
# acctually at step 172
# acctually at step 173
# acctually at step 174
# acctually at step 175
# acctually at step 177
# acctually at step 179
# acctually at step 180
# acctually at step 183
# acctually at step 186
# acctually at step 187
# acctually at step 188
# acctually at step 189
# acctually at step 194
# acctually at step 196
# acctually at step 200
# acctually at step 201
# acctually at step 203
# acctually at step 208
# acctually at step 209
# acctually at step 211
# acctually at step 216
# acctually at step 223
# acctually at step 224
# acctually at step 225
# acctually at step 226
# acctually at step 227
# acctually at step 230
# acctually at step 233
# acctually at step 234
# acctually at step 235
# acctually at step 237
# acctually at step 238
# acctually at step 241
# acctually at step 245
# acctually at step 249
# acctually at step 250
# acctually at step 253
# acctually at step 254
# acctually at step 255
# acctually at step 257
# acctually at step 259
# acctually at step 261
# acctually at step 262
# acctually at step 263
# acctually at step 266
# acctually at step 269
# acctually at step 271
# acctually at step 272
# acctually at step 276
# acctually at step 284
# acctually at step 287
# acctually at step 288
# acctually at step 290
# acctually at step 292
# acctually at step 293
# acctually at step 295
# acctually at step 297
# acctually at step 299
# acctually at step 300
# acctually at step 304
# acctually at step 306
# acctually at step 308
# acctually at step 310
# acctually at step 313
# acctually at step 314
# acctually at step 319
# acctually at step 320
# acctually at step 321
# acctually at step 325
# acctually at step 332
# acctually at step 334
# acctually at step 352
# acctually at step 364
# acctually at step 369
# acctually at step 370
# acctually at step 373
# acctually at step 376
# acctually at step 377
# acctually at step 380
# acctually at step 382
# acctually at step 383
# acctually at step 385
# acctually at step 386
# acctually at step 387
# acctually at step 389
# acctually at step 393
# acctually at step 404
# acctually at step 407
# acctually at step 408
# acctually at step 411
# acctually at step 414
# acctually at step 420
# acctually at step 423
# acctually at step 424
# acctually at step 428
# acctually at step 429
# acctually at step 430
# acctually at step 432
# acctually at step 433
# acctually at step 434
# acctually at step 436
# acctually at step 437
# acctually at step 453
# acctually at step 459
# acctually at step 461
# acctually at step 462
# acctually at step 468
# acctually at step 472
# acctually at step 473
# acctually at step 478
# acctually at step 487
# acctually at step 491
# acctually at step 493
# acctually at step 516
# acctually at step 530
# acctually at step 539
# acctually at step 545
# acctually at step 558
# acctually at step 559
# acctually at step 561
# acctually at step 562
# acctually at step 566
# acctually at step 567
# acctually at step 575
# acctually at step 576
# acctually at step 580
# acctually at step 585
# acctually at step 586
# acctually at step 591
# acctually at step 593
# acctually at step 594
# acctually at step 595
# acctually at step 598
# acctually at step 599
# acctually at step 600
# acctually at step 604
# acctually at step 605
# acctually at step 606
# acctually at step 613
# acctually at step 627
# acctually at step 628
# acctually at step 629
# acctually at step 631
# acctually at step 632
# acctually at step 633
# acctually at step 635
# acctually at step 636
# acctually at step 648
# acctually at step 649
# acctually at step 650
# acctually at step 651
# acctually at step 652
# acctually at step 653
# acctually at step 654
# acctually at step 655
# acctually at step 656
# acctually at step 657
# acctually at step 658
# acctually at step 659
# acctually at step 660
# acctually at step 661
# acctually at step 662
# acctually at step 663
# acctually at step 664
# acctually at step 665
# acctually at step 666
# acctually at step 667
# acctually at step 668
# acctually at step 669
# acctually at step 670
# acctually at step 671
# acctually at step 672
# acctually at step 673
# acctually at step 674
# acctually at step 675
# acctually at step 676
# acctually at step 677
# acctually at step 678
# acctually at step 679
# acctually at step 680
# acctually at step 681
# acctually at step 682
# acctually at step 683
# acctually at step 684
# acctually at step 685
# acctually at step 686
# acctually at step 687
# acctually at step 688
# acctually at step 689
# acctually at step 690
# acctually at step 691
# acctually at step 692
# acctually at step 693
# acctually at step 694
# acctually at step 695
# acctually at step 696
# acctually at step 697
# acctually at step 698
# acctually at step 699
# acctually at step 700
# acctually at step 701
# acctually at step 702
# acctually at step 703
# acctually at step 704
# acctually at step 705
# acctually at step 706
# acctually at step 707
# acctually at step 708
# acctually at step 709
# acctually at step 710
# acctually at step 711
# acctually at step 712
# acctually at step 713
# acctually at step 714
# acctually at step 715
# acctually at step 716
# acctually at step 717
# acctually at step 718
# acctually at step 719
# acctually at step 720
# acctually at step 721
# acctually at step 722
# acctually at step 723
# acctually at step 724
# acctually at step 725
# acctually at step 726
# acctually at step 727
# acctually at step 728
# acctually at step 729
# acctually at step 730
# acctually at step 731
# acctually at step 732
# acctually at step 733
# acctually at step 734
# acctually at step 735
# acctually at step 736
# acctually at step 737
# acctually at step 738
# acctually at step 739
# acctually at step 740
# acctually at step 741
# acctually at step 742
# acctually at step 743
# acctually at step 744
# acctually at step 745
# acctually at step 746
# acctually at step 747
# acctually at step 748
# acctually at step 749
# acctually at step 750
# acctually at step 751
# acctually at step 752
# acctually at step 753
# acctually at step 754
# acctually at step 755
# acctually at step 756
# acctually at step 757
# acctually at step 758
# acctually at step 759
# acctually at step 760
# acctually at step 761
# acctually at step 762
# acctually at step 763
# acctually at step 764
# acctually at step 765
# acctually at step 766
# acctually at step 767
# acctually at step 768
# acctually at step 769
# acctually at step 770
# acctually at step 771
# acctually at step 772
# acctually at step 773
# acctually at step 774
# acctually at step 775
# acctually at step 776
# acctually at step 777
# acctually at step 778
# acctually at step 779
# acctually at step 780
# acctually at step 781
# acctually at step 782
# acctually at step 783
# acctually at step 784
# acctually at step 785
# acctually at step 786
# acctually at step 787
# acctually at step 788
# acctually at step 789
# acctually at step 790
# acctually at step 791
# acctually at step 792
# acctually at step 793
# acctually at step 794
# acctually at step 795
# acctually at step 796
# acctually at step 797
# acctually at step 798
# acctually at step 799
# acctually at step 800
# acctually at step 801
# acctually at step 802
# acctually at step 803
# acctually at step 804
# acctually at step 805
# acctually at step 806
# acctually at step 807
# acctually at step 808
# acctually at step 809
# acctually at step 810
# acctually at step 811
# acctually at step 812
# acctually at step 813
# acctually at step 814
# acctually at step 815
# acctually at step 816
# acctually at step 817
# acctually at step 818
# acctually at step 819
# acctually at step 820
# acctually at step 821
# acctually at step 822
# acctually at step 823
# acctually at step 824
# acctually at step 825
# acctually at step 826
# acctually at step 827
# acctually at step 828
# acctually at step 829
# acctually at step 830
# acctually at step 831
# acctually at step 832
# acctually at step 833
# acctually at step 834
# acctually at step 835
# acctually at step 836
# acctually at step 837
# acctually at step 838
# acctually at step 839
# acctually at step 840
# acctually at step 841
# acctually at step 842
# acctually at step 843
# acctually at step 844
# acctually at step 845
# acctually at step 846
# acctually at step 847
# acctually at step 848
# acctually at step 849
# acctually at step 850
# acctually at step 851
# acctually at step 852
# acctually at step 853
# acctually at step 854
# acctually at step 855
# acctually at step 856
# acctually at step 857
# acctually at step 858
# acctually at step 859
# acctually at step 860
# acctually at step 861
# acctually at step 862
# acctually at step 863
# acctually at step 864
# acctually at step 865
# acctually at step 866
# acctually at step 867
# acctually at step 868
# acctually at step 869
# acctually at step 870
# acctually at step 871
# acctually at step 872
# acctually at step 873
# acctually at step 874
# acctually at step 875
# acctually at step 876
# acctually at step 877
# acctually at step 878
# acctually at step 879
# acctually at step 880
# acctually at step 881
# acctually at step 882
# acctually at step 883
# acctually at step 884
# acctually at step 885
# acctually at step 886
# acctually at step 887
# acctually at step 888
# acctually at step 889
# acctually at step 890
# acctually at step 891
# acctually at step 892
# acctually at step 893
# acctually at step 894
# acctually at step 895
# acctually at step 896
# acctually at step 897
# acctually at step 898
# acctually at step 899
# acctually at step 900
# acctually at step 901
# acctually at step 902
# acctually at step 903
# acctually at step 904
# acctually at step 905
# acctually at step 906
# acctually at step 907
# acctually at step 908
# acctually at step 909
# acctually at step 910
# acctually at step 911
# acctually at step 912
# acctually at step 913
# acctually at step 914
# acctually at step 915
# acctually at step 916
# acctually at step 917
# acctually at step 918
# acctually at step 919
# acctually at step 920
# acctually at step 921
# acctually at step 922
# acctually at step 923
# acctually at step 924
# acctually at step 925
# acctually at step 926
# acctually at step 927
# acctually at step 928
# acctually at step 929
# acctually at step 930
# acctually at step 931
# acctually at step 932
# acctually at step 933
# acctually at step 934
# acctually at step 935
# acctually at step 936
# acctually at step 937
# acctually at step 938
# acctually at step 939
# acctually at step 940
# acctually at step 941
# acctually at step 942
# acctually at step 943
# acctually at step 944
# acctually at step 945
# acctually at step 946
# acctually at step 947
# acctually at step 948
# acctually at step 949
# acctually at step 950
# acctually at step 951
# acctually at step 952
# acctually at step 953
# acctually at step 954
# acctually at step 955
# acctually at step 956
# acctually at step 957
# acctually at step 958
# acctually at step 959
# acctually at step 960
# acctually at step 961
# acctually at step 962
# acctually at step 963
# acctually at step 964
# acctually at step 965
# acctually at step 966
# acctually at step 967
# acctually at step 968
# acctually at step 969
# acctually at step 970
# acctually at step 971
# acctually at step 972
# acctually at step 973
# acctually at step 974
# acctually at step 975
# acctually at step 976
# acctually at step 977
# acctually at step 978
# acctually at step 979
# acctually at step 980
# acctually at step 981
# acctually at step 982
# acctually at step 983
# acctually at step 984
# acctually at step 985
# acctually at step 986
# acctually at step 987
# acctually at step 988
# acctually at step 989
# acctually at step 990
# acctually at step 991
# acctually at step 992
# acctually at step 993
# acctually at step 994
# acctually at step 995
# acctually at step 996
# acctually at step 997
# acctually at step 998
# acctually at step 999
# acctually at step 1000
# acctually at step 1001
# acctually at step 1002
# acctually at step 1003
# acctually at step 1004
# acctually at step 1005
# acctually at step 1006
# acctually at step 1007
# acctually at step 1008
# acctually at step 1009
# acctually at step 1010
# acctually at step 1011
# acctually at step 1012
# acctually at step 1013
# acctually at step 1014
# acctually at step 1015
# acctually at step 1016
# acctually at step 1017
# acctually at step 1018
# acctually at step 1019
# acctually at step 1020
# acctually at step 1021
# acctually at step 1022
# acctually at step 1023
# acctually at step 1024
# acctually at step 1025
# acctually at step 1026
# acctually at step 1027
# acctually at step 1028
# acctually at step 1029
# acctually at step 1030
# acctually at step 1031
# acctually at step 1032
# acctually at step 1033
# acctually at step 1034
# acctually at step 1035
# acctually at step 1036
# acctually at step 1037
# acctually at step 1038
# acctually at step 1039
# acctually at step 1040
# acctually at step 1041
# acctually at step 1042
# acctually at step 1043
# acctually at step 1044
# acctually at step 1045
# acctually at step 1046
# acctually at step 1047
# acctually at step 1350
# acctually at step 1351
# acctually at step 1352
# acctually at step 1353
# acctually at step 1354
# acctually at step 1355
# acctually at step 1356
# acctually at step 1357
# acctually at step 1358
# acctually at step 1359
# acctually at step 1360
# acctually at step 1361
# acctually at step 1362
# acctually at step 1363
# acctually at step 1364
# acctually at step 1365
# acctually at step 1366
# acctually at step 1367
# acctually at step 1368
# acctually at step 1369
# acctually at step 1370
# acctually at step 1371
# acctually at step 1372
# acctually at step 1373
# acctually at step 1374
# acctually at step 1375
# acctually at step 1376
# acctually at step 1377
# acctually at step 1378
# acctually at step 1379
# acctually at step 1380
# acctually at step 1381
# acctually at step 1382
# acctually at step 1383
# acctually at step 1384
# acctually at step 1385
# acctually at step 1386
# acctually at step 1387
# acctually at step 1388
# acctually at step 1389
# acctually at step 1390
# acctually at step 1391
# acctually at step 1392
# acctually at step 1393
# acctually at step 1394
# acctually at step 1395
# acctually at step 1396
# acctually at step 1397
# acctually at step 1398
# acctually at step 1399
# acctually at step 1400
# acctually at step 1401
# acctually at step 1402
# acctually at step 1403
# acctually at step 1404
# acctually at step 1405
# acctually at step 1406
# acctually at step 1407
# acctually at step 1408
# acctually at step 1409
# acctually at step 1410
# acctually at step 1411
# acctually at step 1412
# acctually at step 1413
# acctually at step 1414
# acctually at step 1415
# acctually at step 1416
# acctually at step 1417
# acctually at step 1418
# acctually at step 1419
# acctually at step 1420
# acctually at step 1421
# acctually at step 1422
# acctually at step 1423
# acctually at step 1424
# acctually at step 1425
# acctually at step 1426
# acctually at step 1427
# acctually at step 1428
# acctually at step 1429
# acctually at step 1430

# %%
df_addr.head(100)
# Out:
#                                               address  \
# 0        -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1             "Almaly Village" v.5, Almaty Kazakhstan
# 2   "Cantonia" South Road St Georges Hill Weybridg...
# 3   "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4   "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
# 5    "La Diana"; 16 rue Del Respiro; MC 98000 Monaco.
# 6   "Les hauts de St Jean"; 17 avenue Perdtemts; C...
# 7           "Les Tattes"; Bursinel; Vaud; Switzerland
# 8   "Quai Kennedy" 1 boulevard Louis II Monaco MC9...
# 9   "Sofia House" 48 Church Street; 1st Floor; Ham...
# 10  "Sunchine" Flat 1; Triq il-Huttaf; Mosta MST 1...
# 11  "Touchstone"; Ardbraccan; Navan; County Meath;...
# 12  "VILLA" RAMY-MANDROSOA-IV ATO-IVATO FIRAISENA ...
# 13  "Whingate" Tower Hill Dummer; Nr Basingstoke; ...
# 14   #02-01; 14 MOHAMED SULTAN ROAD; SINGAPORE 238963
# 15  #04-08 NOVENA SUITES; 200 MOULMEIN ROAD; SINGA...
# 16  #04-263; Block 255; ST21 Pasir Ris; 510255; Si...
# 17  #06-03 Montrosa; 132 B Hillview Ave; Singapore...
# 18  #068 Purok 1 Barangay; Salvacion 2nd; Lupao Nu...
# 25  Panama Papers  NaN   0.000000     0    0.000000
# 26  Panama Papers  NaN  31.213235     0  121.479463
# 27  Panama Papers  NaN   3.094486     0  101.647598
# 28  Panama Papers  NaN  30.245369     0  120.173056
# 29  Panama Papers  NaN  30.295028     0  120.136782
# ..            ...  ...        ...   ...         ...
# 70  Panama Papers  NaN  17.501015     0  -88.192918
# 71  Panama Papers  NaN   0.000000     0    0.000000
# 72  Panama Papers  NaN   0.000000     0    0.000000
# 73  Panama Papers  NaN   0.000000     0    0.000000
# 74  Panama Papers  NaN   0.000000     0    0.000000
# 75  Panama Papers  NaN  23.170784     0  113.324394
# 76  Panama Papers  NaN  34.287374     0  108.868904
# 77  Panama Papers  NaN   0.000000     0    0.000000
# 78  Panama Papers  NaN  35.741389     0  139.991702
# 79  Panama Papers  NaN  49.288642     0 -123.123447
# 80  Panama Papers  NaN  14.563277     0  121.026967
# 81  Panama Papers  NaN  49.223409     0 -123.005350
# 82  Panama Papers  NaN  22.268712     0  114.152958
# 83  Panama Papers  NaN  36.081302     0  120.383672
# 84  Panama Papers  NaN  37.502153     0  126.912422
# 85  Panama Papers  NaN  36.788312     0  118.044571
# 86  Panama Papers  NaN   0.000000     0    0.000000
# 87  Panama Papers  NaN   0.000000     0    0.000000
# 88  Panama Papers  NaN   0.000000     0    0.000000
# 89  Panama Papers  NaN   0.000000     0    0.000000
# 90  Panama Papers  NaN  33.641782     0 -117.721276
# 91  Panama Papers  NaN   0.000000     0    0.000000
# 92  Panama Papers  NaN   0.000000     0    0.000000
# 93  Panama Papers  NaN   0.000000     0    0.000000
# 94  Panama Papers  NaN   0.000000     0    0.000000
# 95  Panama Papers  NaN   0.000000     0    0.000000
# 96  Panama Papers  NaN   0.000000     0    0.000000
# 97  Panama Papers  NaN   0.000000     0    0.000000
# 98  Panama Papers  NaN   0.000000     0    0.000000
# 99  Panama Papers  NaN   0.000000     0    0.000000
#
# [100 rows x 10 columns]

# %%
g = geocoder.google(addr)

# %%
g.latlng

# %%
for i in range(5): #len(df_addr['address'])
    addr = df_addr['address'][i]
    print(geocoder.google(addr).latlng)
# Out:
# None
# None
# None
# None
# None

# %%
addr = df_addr['address'][3]
print(geocoder.google(addr).latlng)
# Out:
# None

# %% [markdown]
# ## Edges Dataframe

# %%
df_edges = pd.read_csv(all_edges)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_edges.head()
# Out:
#      node_1         rel_type    node_2       sourceID  \
# 0  11000001  intermediary of  10208879  Panama Papers
# 1  11000001  intermediary of  10198662  Panama Papers
# 2  11000001  intermediary of  10159927  Panama Papers
# 3  11000001  intermediary of  10165779  Panama Papers
# 4  11000001  intermediary of  10152967  Panama Papers
#
#                                       valid_until start_date end_date
# 0  The Panama Papers data is current through 2015        NaN      NaN
# 1  The Panama Papers data is current through 2015        NaN      NaN
# 2  The Panama Papers data is current through 2015        NaN      NaN
# 3  The Panama Papers data is current through 2015        NaN      NaN
# 4  The Panama Papers data is current through 2015        NaN      NaN

# %%
print('The dataset involve {} entries'.format(df_edges.size))
# Out:
# The dataset involve 10748864 entries

# %% [markdown]
# - Rel_type is the type of the relation btw two entities (nodes) ex: 12000001 shareholder of 10073324
# - node_1 and node_2 are entities (company or individual)
# - start and end date are the date of beginning and end of the relationship

# %%
Counter(df_edges['sourceID'])
# Out:
# Counter({'Panama Papers': 674102,
#          'Offshore Leaks': 561393,
#          'Bahamas Leaks': 249190,
#          nan: 50867})

# %%
Counter(df_edges['valid_until'])
# Out:
# Counter({'The Panama Papers data is current through 2015': 668691,
#          'The Offshore Leaks data is current through 2010': 561393,
#          'The Bahamas Leaks data is current through early 2016.': 249190,
#          'The Panama Papers  data is current through 2015': 101,
#          nan: 56177})

# %% [markdown]
# Again we can drop the valid_until col - note: there is a typo on The Panama Papers data is current through 2015. - And here we don't have the same number for Panama papers SourceID and The Panama Papers data is current through 2015 valid_until

# %%
df_edges = df_edges.drop('valid_until', 1)

# %%
df_edges['start_date'] = pd.to_datetime(df_edges['start_date'], errors = 'coerce')
df_edges['end_date'] = pd.to_datetime(df_edges['end_date'], errors = 'coerce')

# %%
df_edges['sourceID'] =  df_edges['sourceID'].astype('category')

# %% [markdown]
# ## Entities Dataframe

# %%
df_entities = pd.read_csv(entities, dtype = {'original_name': str, 'former_name':str,'company_type':str, 'address':str, 'status': str,'service_provider': str, 'country_codes':str, 'countries': str, 'note':str })
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_entities.dtypes
# Out:
# name                         object
# original_name                object
# former_name                  object
# jurisdiction                 object
# jurisdiction_description     object
# company_type                 object
# address                      object
# internal_id                 float64
# incorporation_date           object
# inactivation_date            object
# struck_off_date              object
# dorm_date                    object
# status                       object
# service_provider             object
# ibcRUC                       object
# country_codes                object
# countries                    object
# note                         object
# valid_until                  object
# node_id                       int64
# sourceID                     object
# dtype: object

# %%
print('The dataset involve {} entries'.format(df_entities.size))
# Out:
# The dataset involve 10395798 entries

# %%
df_entities.columns
# Out:
# Index(['name', 'original_name', 'former_name', 'jurisdiction',
#        'jurisdiction_description', 'company_type', 'address', 'internal_id',
#        'incorporation_date', 'inactivation_date', 'struck_off_date',
#        'dorm_date', 'status', 'service_provider', 'ibcRUC', 'country_codes',
#        'countries', 'note', 'valid_until', 'node_id', 'sourceID'],
#       dtype='object')

# %%
df_entities
# Out:
#                                                 name  \
# 0           TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1        NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2                                 HOTFOCUS CO., LTD.
# 3                    SKY-BLUE GIFTS & TOYS CO., LTD.
# 4               FORTUNEMAKER INVESTMENTS CORPORATION
# 5                               8808 HOLDING LIMITED
# 6                           KENT DEVELOPMENT LIMITED
# 7                                BONUS TRADE LIMITED
# 8                                     AMARANDAN LTD.
# 9                                   NEW IDEA LIMITED
# 10                                HUGH POWER LIMITED
# 11                            ULTIMATE GROUP LIMITED
# 12                             VICTORY GROUP LIMITED
# 13                              CHARTER MARK LIMITED
# 14              Wide International Trading Co., Ltd.
# 15                           HTSS ET CAPITAL LIMITED
# 22                           PRESTIGE INTERNATIONAL CORP.
# 23                   SUNNY TREASURE INTERNATIONAL LIMITED
# 24                                            GIT CO INC.
# 25                           EURO INVESTMENT CAPITAL INC.
# 26                          WORLD TOOLS INVESTMENTS CORP.
# 27                                     WINESELECTION S.A.
# 28                               NECY CONSULTANTS LIMITED
# 29                                KIND INTERNATIONAL INC.
# ...                                                   ...
# 495008                                  Penlee Foundation
# 495009                                VALHALLA FOUNDATION
# 495010                                 Strelka Foundation
# 495011                        The Oasis Family Foundation
# 495012                  HISTORIC CHARLES TOWNE FOUNDATION
# 495013                                IL CARES FOUNDATION
# 495014                             OWN BAHAMAS FOUNDATION
# 495015                 THE MYLES & RUTH MUNROE FOUNDATION
# 495016                                THE FTAR FOUNDATION
# 495017                      Bellemar Community Foundation
# 495018                                THE BIMA FOUNDATION
# 495019                              THE ARISTI FOUNDATION
# 495020                      The Future Private Foundation
# 495021                             The Ertalia Foundation
# 495022                               Earlshill Foundation
# 495023                                  GUALCA FOUNDATION
# 495024                                  BEACON FOUNDATION
# 495025                         Southern Galaxy Foundation
# 495026                                 QUDURAT FOUNDATION
# 495027                        STALLIONS UNITED FOUNDATION
# 495028                The Paul Mark Hoffenberg Foundation
# 495029             The GDS Gold Silver Diamond Foundation
# 495030                                     CEP Foundation
# 495031                       The Kamla Diamond Foundation
# 495032                      THE KAMALA DIAMOND FOUNDATION
# 495033                                   Malno Foundation
# 495034                          HARD WORK LIFE FOUNDATION
# 495035                             FIORDILATTE FOUNDATION
# 495036                                  Paweco Foundation
# 495037                                    Beli Foundation
#
#                      former_name jurisdiction jurisdiction_description  \
# 0                            NaN          SAM                    Samoa
# 1                            NaN          SAM                    Samoa
# 2                            NaN          SAM                    Samoa
# 3                            NaN          SAM                    Samoa
# 4                            NaN          SAM                    Samoa
# 5                DIAMOND LIMITED          SAM                    Samoa
# 6                            NaN          SAM                    Samoa
# 7                            NaN          SAM                    Samoa
# 8                            NaN          SAM                    Samoa
# 9                            NaN          SAM                    Samoa
# 10                           NaN          SAM                    Samoa
# 11                           NaN          SAM                    Samoa
# 12                           NaN          SAM                    Samoa
# 13                           NaN          SAM                    Samoa
# 14                           NaN          SAM                    Samoa
# 15                           NaN          SAM                    Samoa
# 16                           NaN          SAM                    Samoa
# 17                           NaN          SAM                    Samoa
# 18      QUEENSLAND OVERSEAS LTD.          SAM                    Samoa
# 19                           NaN          SAM                    Samoa
# 20                           NaN          SAM                    Samoa
# 21                 CHEM DT Corp.          SAM                    Samoa
# 22                           NaN          SAM                    Samoa
# 23                           NaN          SAM                    Samoa
# 24                           NaN          SAM                    Samoa
# 25                           NaN          SAM                    Samoa
# 26                           NaN          SAM                    Samoa
# 27                           NaN          SAM                    Samoa
# 28                           NaN          SAM                    Samoa
# 29                           NaN          SAM                    Samoa
# ...                          ...          ...                      ...
# 495008                       NaN          BAH                  Bahamas
# 495009                       NaN          BAH                  Bahamas
# 495010                       NaN          BAH                  Bahamas
# 495011                       NaN          BAH                  Bahamas
# 495012                       NaN          BAH                  Bahamas
# 495013                       NaN          BAH                  Bahamas
# 495014                       NaN          BAH                  Bahamas
# 495015                       NaN          BAH                  Bahamas
# 495016                       NaN          BAH                  Bahamas
# 495017                       NaN          BAH                  Bahamas
# 495018                       NaN          BAH                  Bahamas
# 495019                       NaN          BAH                  Bahamas
# 495020                       NaN          BAH                  Bahamas
# 495021                       NaN          BAH                  Bahamas
# 495022                       NaN          BAH                  Bahamas
# 495023                       NaN          BAH                  Bahamas
# 495024                       NaN          BAH                  Bahamas
# 495025                       NaN          BAH                  Bahamas
# 495026                       NaN          BAH                  Bahamas
# 495027                       NaN          BAH                  Bahamas
# 495028                       NaN          BAH                  Bahamas
# 495029                       NaN          BAH                  Bahamas
# 495030                       NaN          BAH                  Bahamas
# 495031                       NaN          BAH                  Bahamas
# 495032                       NaN          BAH                  Bahamas
# 495033                       NaN          BAH                  Bahamas
# 495034                       NaN          BAH                  Bahamas
# 495035                       NaN          BAH                  Bahamas
# 495036                       NaN          BAH                  Bahamas
# 495037                       NaN          BAH                  Bahamas
#
#        company_type                                            address  \
# 0               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 1               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 2               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 3               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 4               NaN  LOYAL PORT LIMITED 8/F; CRAWFORD TOWER 99 JERV...
# 5               NaN  TWC MANAGEMENT LIMITED SUITE D; 19/F RITZ PLAZ...
# 6               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 7               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 8               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 9               NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 10              NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 11              NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 12              NaN  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 13              NaN  AFOR LAW FIRM, SICHUAN CHENGDU SHUANGNAN PIK W...
# 14              NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 15              NaN  TWC MANAGEMENT LIMITED SUITE D; 19/F RITZ PLAZ...
# 16              NaN  MEI SERVICES LIMITED ROOM E; 6TH FLOOR; EASTER...
# 17              NaN  AFOR LAW FIRM, SICHUAN CHENGDU SHUANGNAN PIK W...
# 18              NaN  FCI LTD. ATT.: MR. DAVID RISBEY POSTFACH 24 72...
# 19              NaN  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 20              NaN  MOSSACK FONSECA & CO. (SINGAPORE) PTE LTD.  19...
# 21              NaN  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 22              NaN  GO SHINE MANAGEMENT CO.; LTD. ROOM B; 5F.; NO....
# 23              NaN  DI SAN DI MANAGEMENT COMPANY LIMITED 7F- 4; NO...
# 24              NaN  MR. SPYRO A. METAXAS RUE DE HESSE 16 CASE POST...
# 25              NaN  MR. SPYRO A. METAXAS RUE DE HESSE 16 CASE POST...
# 26              NaN  MIGUEL NETO ADVOGADOS RUA GUARARAPES; 1909 CON...
# 27              NaN  MSG S.A. 5, CH. DE LA VUACHÈRE CASE POSTALE 10...
# 28              NaN  WILLIE MANAGEMENT LIMITED 12TH FLOOR; LUCKY BU...
# 29              NaN  SINO-WEST INTERNATIONAL CO.; LTD. 3F-6; NO. 36...
# ...             ...                                                ...
# 495008          NaN                                                NaN
# 495009          NaN                                                NaN
# 495010          NaN                                                NaN
# 495011          NaN                                                NaN
# 495012          NaN                                                NaN
# 495013          NaN                                                NaN
# 495014          NaN                                                NaN
# 495015          NaN                                                NaN
# 495016          NaN                                                NaN
# 495017          NaN                                                NaN
# 495018          NaN                                                NaN
# 495019          NaN                                                NaN
# 495020          NaN                                                NaN
# 495021          NaN                                                NaN
# 495022          NaN                                                NaN
# 495023          NaN                                                NaN
# 495024          NaN                                                NaN
# 495025          NaN                                                NaN
# 495026          NaN                                                NaN
# 495027          NaN                                                NaN
# 495028          NaN                                                NaN
# 495029          NaN                                                NaN
# 495030          NaN                                                NaN
# 495031          NaN                                                NaN
# 495032          NaN                                                NaN
# 495033          NaN                                                NaN
# 495034          NaN                                                NaN
# 495035          NaN                                                NaN
# 495036          NaN                                                NaN
# 495037          NaN                                                NaN
#
#         internal_id incorporation_date inactivation_date      ...        \
# 0         1001256.0        23-MAR-2006       18-FEB-2013      ...
# 1         1001263.0        27-MAR-2006       27-FEB-2014      ...
# 2         1000896.0        10-JAN-2006       15-FEB-2012      ...
# 3         1000914.0        06-JAN-2006       16-FEB-2009      ...
# 4         1001266.0        19-APR-2006       15-MAY-2009      ...
# 5         1000916.0        05-JAN-2006               NaN      ...
# 6         1000022.0        26-JAN-2004       03-MAY-2006      ...
# 7         1000049.0        13-FEB-2004       16-FEB-2009      ...
# 8         1000024.0        26-JAN-2004       03-MAY-2006      ...
# 9         1000079.0        30-MAR-2004       27-FEB-2007      ...
# 10        1000081.0        30-MAR-2004       02-JAN-2008      ...
# 11        1000095.0        05-APR-2004               NaN      ...
# 12        1000077.0        30-MAR-2004       20-FEB-2010      ...
# 13        1000052.0        13-FEB-2004       17-FEB-2011      ...
# 14        1000935.0        06-JAN-2006               NaN      ...
# 15        1001721.0        21-AUG-2006       19-FEB-2015      ...
# 16        1001323.0        10-APR-2006               NaN      ...
# 17        1000087.0        29-MAR-2004       03-MAY-2006      ...
# 18        1000054.0        06-FEB-2004       01-FEB-2005      ...
# 19        1000944.0        12-JAN-2006       27-FEB-2014      ...
# 20        1000004.0        26-JAN-2004       03-MAY-2006      ...
# 21        1000094.0        30-MAR-2004       06-NOV-2009      ...
# 22        1000149.0        10-JUN-2004               NaN      ...
# 23        1000042.0        06-FEB-2004       03-MAY-2006      ...
# 24        1001840.0        21-NOV-2006       30-AUG-2014      ...
# 25        1001857.0        27-OCT-2006       15-FEB-2012      ...
# 26        1002212.0        19-DEC-2006       29-APR-2009      ...
# 27        1002232.0        29-DEC-2006       19-FEB-2015      ...
# 28        1000953.0        22-MAR-2006               NaN      ...
# 29        1001744.0        07-SEP-2006       19-FEB-2015      ...
# ...             ...                ...               ...      ...
# 495008        713.0        07-SEP-2015               NaN      ...
# 495009        714.0        09-SEP-2015               NaN      ...
# 495010        715.0        11-SEP-2015               NaN      ...
# 495011        716.0        29-SEP-2015               NaN      ...
# 495012        717.0        28-SEP-2015               NaN      ...
# 495013        718.0        09-OCT-2015               NaN      ...
# 495014        719.0        09-OCT-2015               NaN      ...
# 495015        720.0        27-OCT-2015               NaN      ...
# 495016        721.0        05-NOV-2015               NaN      ...
# 495017        722.0        18-NOV-2015               NaN      ...
# 495018        723.0        25-NOV-2015               NaN      ...
# 495019        724.0        24-NOV-2015               NaN      ...
# 495020        725.0        14-DEC-2015               NaN      ...
# 495021        726.0        08-DEC-2015               NaN      ...
# 495022        727.0        22-DEC-2015               NaN      ...
# 495023        728.0        11-DEC-2015               NaN      ...
# 495024        729.0        05-JAN-2016               NaN      ...
# 495025        730.0        05-JAN-2016               NaN      ...
# 495026        731.0        21-DEC-2015               NaN      ...
# 495027        732.0        26-JAN-2016               NaN      ...
# 495028        733.0        21-JAN-2016               NaN      ...
# 495029        734.0        26-JAN-2016               NaN      ...
# 495030        735.0        18-JAN-2016               NaN      ...
# 495031        736.0        01-FEB-2016               NaN      ...
# 495032        737.0        01-FEB-2016               NaN      ...
# 495033        738.0        10-FEB-2016               NaN      ...
# 495034        739.0        02-FEB-2016               NaN      ...
# 495035        740.0        19-FEB-2016               NaN      ...
# 495036        741.0        07-MAR-2016               NaN      ...
# 495037        742.0        01-MAR-2016               NaN      ...
#
#        dorm_date                         status service_provider  ibcRUC  \
# 0            NaN                      Defaulted  Mossack Fonseca   25221
# 1            NaN                      Defaulted  Mossack Fonseca   25249
# 2            NaN                      Defaulted  Mossack Fonseca   24138
# 3            NaN                      Defaulted  Mossack Fonseca   24012
# 4            NaN                  Changed agent  Mossack Fonseca  R25638
# 5            NaN                         Active  Mossack Fonseca   23835
# 6            NaN                      Defaulted  Mossack Fonseca   15757
# 7            NaN                      Defaulted  Mossack Fonseca   15910
# 8            NaN                      Defaulted  Mossack Fonseca   15759
# 9            NaN                      Defaulted  Mossack Fonseca   16462
# 10           NaN                      Defaulted  Mossack Fonseca   16464
# 11           NaN                         Active  Mossack Fonseca   16573
# 12           NaN                      Defaulted  Mossack Fonseca   16460
# 13           NaN                      Defaulted  Mossack Fonseca   15913
# 14           NaN                         Active  Mossack Fonseca   24014
# 15           NaN                      Defaulted  Mossack Fonseca   27502
# 16           NaN                         Active  Mossack Fonseca   25475
# 17           NaN                      Defaulted  Mossack Fonseca   16408
# 18           NaN                    Inactivated  Mossack Fonseca   15858
# 19           NaN                      Defaulted  Mossack Fonseca   24181
# 20           NaN                      Defaulted  Mossack Fonseca   15774
# 21           NaN                      Defaulted  Mossack Fonseca   16469
# 22           NaN                         Active  Mossack Fonseca   17370
# 23           NaN                      Defaulted  Mossack Fonseca   15857
# 24           NaN                      Defaulted  Mossack Fonseca  R28975
# 25           NaN                      Defaulted  Mossack Fonseca  R28631
# 26           NaN  Relocated in new jurisdiction  Mossack Fonseca  R29502
# 27           NaN                      Defaulted  Mossack Fonseca  R29714
# 28           NaN                         Active  Mossack Fonseca  R25192
# 29           NaN                      Defaulted  Mossack Fonseca  R27848
# ...          ...                            ...              ...     ...
# 495008       NaN                            NaN              NaN    713B
# 495009       NaN                            NaN              NaN    714B
# 495010       NaN                            NaN              NaN    715B
# 495011       NaN                            NaN              NaN    716B
# 495012       NaN                            NaN              NaN    717B
# 495013       NaN                            NaN              NaN    718B
# 495014       NaN                            NaN              NaN    719B
# 495015       NaN                            NaN              NaN    720B
# 495016       NaN                            NaN              NaN    721B
# 495017       NaN                            NaN              NaN    722B
# 495018       NaN                            NaN              NaN    723B
# 495019       NaN                            NaN              NaN    724B
# 495020       NaN                            NaN              NaN    725B
# 495021       NaN                            NaN              NaN    726B
# 495022       NaN                            NaN              NaN    727B
# 495023       NaN                            NaN              NaN    728B
# 495024       NaN                            NaN              NaN    729B
# 495025       NaN                            NaN              NaN    730B
# 495026       NaN                            NaN              NaN    731B
# 495027       NaN                            NaN              NaN    732B
# 495028       NaN                            NaN              NaN    733B
# 495029       NaN                            NaN              NaN    734B
# 495030       NaN                            NaN              NaN    735B
# 495031       NaN                            NaN              NaN    736B
# 495032       NaN                            NaN              NaN    737B
# 495033       NaN                            NaN              NaN    738B
# 495034       NaN                            NaN              NaN    739B
# 495035       NaN                            NaN              NaN    740B
# 495036       NaN                            NaN              NaN    741B
# 495037       NaN                            NaN              NaN    742B
#
#        country_codes    countries note  \
# 0                HKG    Hong Kong  NaN
# 1                HKG    Hong Kong  NaN
# 2                HKG    Hong Kong  NaN
# 3                HKG    Hong Kong  NaN
# 4                HKG    Hong Kong  NaN
# 5                HKG    Hong Kong  NaN
# 6                HKG    Hong Kong  NaN
# 7                HKG    Hong Kong  NaN
# 8                HKG    Hong Kong  NaN
# 9                HKG    Hong Kong  NaN
# 10               HKG    Hong Kong  NaN
# 11               HKG    Hong Kong  NaN
# 12               TWN       Taiwan  NaN
# 13               CHN        China  NaN
# 14               HKG    Hong Kong  NaN
# 15               HKG    Hong Kong  NaN
# 16               HKG    Hong Kong  NaN
# 17               CHN        China  NaN
# 18               CHE  Switzerland  NaN
# 19               HKG    Hong Kong  NaN
# 20               SGP    Singapore  NaN
# 21               TWN       Taiwan  NaN
# 22               TWN       Taiwan  NaN
# 23               TWN       Taiwan  NaN
# 24               CHE  Switzerland  NaN
# 25               CHE  Switzerland  NaN
# 26               BRA       Brazil  NaN
# 27               CHE  Switzerland  NaN
# 28               HKG    Hong Kong  NaN
# 29               TWN       Taiwan  NaN
# ...              ...          ...  ...
# 495008           NaN          NaN  NaN
# 495009           NaN          NaN  NaN
# 495010           NaN          NaN  NaN
# 495011           NaN          NaN  NaN
# 495012           NaN          NaN  NaN
# 495013           NaN          NaN  NaN
# 495014           NaN          NaN  NaN
# 495015           NaN          NaN  NaN
# 495016           NaN          NaN  NaN
# 495017           NaN          NaN  NaN
# 495018           NaN          NaN  NaN
# 495019           NaN          NaN  NaN
# 495020           NaN          NaN  NaN
# 495021           NaN          NaN  NaN
# 495022           NaN          NaN  NaN
# 495023           NaN          NaN  NaN
# 495024           NaN          NaN  NaN
# 495025           NaN          NaN  NaN
# 495026           NaN          NaN  NaN
# 495027           NaN          NaN  NaN
# 495028           NaN          NaN  NaN
# 495029           NaN          NaN  NaN
# 495030           NaN          NaN  NaN
# 495031           NaN          NaN  NaN
# 495032           NaN          NaN  NaN
# 495033           NaN          NaN  NaN
# 495034           NaN          NaN  NaN
# 495035           NaN          NaN  NaN
# 495036           NaN          NaN  NaN
# 495037           NaN          NaN  NaN
#
#                                               valid_until   node_id  \
# 0          The Panama Papers data is current through 2015  10000001
# 1          The Panama Papers data is current through 2015  10000002
# 2          The Panama Papers data is current through 2015  10000003
# 3          The Panama Papers data is current through 2015  10000004
# 4          The Panama Papers data is current through 2015  10000005
# 5          The Panama Papers data is current through 2015  10000006
# 6          The Panama Papers data is current through 2015  10000007
# 7          The Panama Papers data is current through 2015  10000008
# 8          The Panama Papers data is current through 2015  10000009
# 9          The Panama Papers data is current through 2015  10000010
# 10         The Panama Papers data is current through 2015  10000011
# 11         The Panama Papers data is current through 2015  10000012
# 12         The Panama Papers data is current through 2015  10000013
# 13         The Panama Papers data is current through 2015  10000014
# 14         The Panama Papers data is current through 2015  10000015
# 15         The Panama Papers data is current through 2015  10000019
# 16         The Panama Papers data is current through 2015  10000020
# 17         The Panama Papers data is current through 2015  10000021
# 18         The Panama Papers data is current through 2015  10000024
# 19         The Panama Papers data is current through 2015  10000016
# 20         The Panama Papers data is current through 2015  10000017
# 21         The Panama Papers data is current through 2015  10000018
# 22         The Panama Papers data is current through 2015  10000022
# 23         The Panama Papers data is current through 2015  10000023
# 24         The Panama Papers data is current through 2015  10000025
# 25         The Panama Papers data is current through 2015  10000026
# 26         The Panama Papers data is current through 2015  10000027
# 27         The Panama Papers data is current through 2015  10000028
# 28         The Panama Papers data is current through 2015  10000029
# 29         The Panama Papers data is current through 2015  10000030
# ...                                                   ...       ...
# 495008  The Bahamas Leaks data is current through earl...  21000713
# 495009  The Bahamas Leaks data is current through earl...  21000714
# 495010  The Bahamas Leaks data is current through earl...  21000715
# 495011  The Bahamas Leaks data is current through earl...  21000716
# 495012  The Bahamas Leaks data is current through earl...  21000717
# 495013  The Bahamas Leaks data is current through earl...  21000718
# 495014  The Bahamas Leaks data is current through earl...  21000719
# 495015  The Bahamas Leaks data is current through earl...  21000720
# 495016  The Bahamas Leaks data is current through earl...  21000721
# 495017  The Bahamas Leaks data is current through earl...  21000722
# 495018  The Bahamas Leaks data is current through earl...  21000723
# 495019  The Bahamas Leaks data is current through earl...  21000724
# 495020  The Bahamas Leaks data is current through earl...  21000725
# 495021  The Bahamas Leaks data is current through earl...  21000726
# 495022  The Bahamas Leaks data is current through earl...  21000727
# 495023  The Bahamas Leaks data is current through earl...  21000728
# 495024  The Bahamas Leaks data is current through earl...  21000729
# 495025  The Bahamas Leaks data is current through earl...  21000730
# 495026  The Bahamas Leaks data is current through earl...  21000731
# 495027  The Bahamas Leaks data is current through earl...  21000732
# 495028  The Bahamas Leaks data is current through earl...  21000733
# 495029  The Bahamas Leaks data is current through earl...  21000734
# 495030  The Bahamas Leaks data is current through earl...  21000735
# 495031  The Bahamas Leaks data is current through earl...  21000736
# 495032  The Bahamas Leaks data is current through earl...  21000737
# 495033  The Bahamas Leaks data is current through earl...  21000738
# 495034  The Bahamas Leaks data is current through earl...  21000739
# 495035  The Bahamas Leaks data is current through earl...  21000740
# 495036  The Bahamas Leaks data is current through earl...  21000741
# 495037  The Bahamas Leaks data is current through earl...  21000742
#
#              sourceID
# 0       Panama Papers
# 1       Panama Papers
# 2       Panama Papers
# 3       Panama Papers
# 4       Panama Papers
# 5       Panama Papers
# 6       Panama Papers
# 7       Panama Papers
# 8       Panama Papers
# 9       Panama Papers
# 10      Panama Papers
# 11      Panama Papers
# 12      Panama Papers
# 13      Panama Papers
# 14      Panama Papers
# 15      Panama Papers
# 16      Panama Papers
# 17      Panama Papers
# 18      Panama Papers
# 19      Panama Papers
# 20      Panama Papers
# 21      Panama Papers
# 22      Panama Papers
# 23      Panama Papers
# 24      Panama Papers
# 25      Panama Papers
# 26      Panama Papers
# 27      Panama Papers
# 28      Panama Papers
# 29      Panama Papers
# ...               ...
# 495008  Bahamas Leaks
# 495009  Bahamas Leaks
# 495010  Bahamas Leaks
# 495011  Bahamas Leaks
# 495012  Bahamas Leaks
# 495013  Bahamas Leaks
# 495014  Bahamas Leaks
# 495015  Bahamas Leaks
# 495016  Bahamas Leaks
# 495017  Bahamas Leaks
# 495018  Bahamas Leaks
# 495019  Bahamas Leaks
# 495020  Bahamas Leaks
# 495021  Bahamas Leaks
# 495022  Bahamas Leaks
# 495023  Bahamas Leaks
# 495024  Bahamas Leaks
# 495025  Bahamas Leaks
# 495026  Bahamas Leaks
# 495027  Bahamas Leaks
# 495028  Bahamas Leaks
# 495029  Bahamas Leaks
# 495030  Bahamas Leaks
# 495031  Bahamas Leaks
# 495032  Bahamas Leaks
# 495033  Bahamas Leaks
# 495034  Bahamas Leaks
# 495035  Bahamas Leaks
# 495036  Bahamas Leaks
# 495037  Bahamas Leaks
#
# [495038 rows x 21 columns]

# %% [markdown]
# - name, original name, and former_name when there was a change are string
# - jurisdiction: country code of the country of jurisdiction - XXX when nan values
# - jurisdiction_description: name of the country - redondant from previous one
# - compagny_type: string describe the compagny type (ex: Standard International Company) take care some error
# - internal_id ?
# - incorporation_date: The date when an offshore entity was created.
# - inactivation_date: The date when a client told the agent to deactivate the offshore entity, which could be reactivated at a later date.
# - struck_off_date: A company becomes struck off when it fails to be in good standing, which happens when it fails to pay license fees. In the offshore world this is the equivalent to closing an entity, although it can be reactivated at a later date if the fees start being paid again.
# - dorm_date: The date when an offshore entity stopped being active.
# - statuts: information that relates to the jurisdiction where an entity may have fiscal duties
# - service_provider: who provide the leaks
# - ibcRUC:

# %%
df_entities['incorporation_date'] = pd.to_datetime(df_entities['incorporation_date'], errors = 'coerce')
df_entities['inactivation_date'] = pd.to_datetime(df_entities['inactivation_date'], errors = 'coerce')
df_entities['struck_off_date'] = pd.to_datetime(df_entities['struck_off_date'], errors = 'coerce')
df_entities['dorm_date'] = pd.to_datetime(df_entities['dorm_date'], errors = 'coerce')
